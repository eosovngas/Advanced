# %%
import json

# %%
n1=7
try:
    print(f"Numero 1: {n1}")
except Exception as e:
    mssparkutils.notebook.exit(f"ERROR al ingresar numero 1 para la suma: {str(e)}")
 
mssparkutils.notebook.exit(
    json.dumps({
        "status": "OK",
        "n1":n1,
        "source": "Numero 1"
        })
)
