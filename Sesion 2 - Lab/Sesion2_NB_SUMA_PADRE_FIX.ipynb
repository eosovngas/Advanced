# %%
import json

# %%
# %run

# %%
resultado_nb_n1_suma = mssparkutils.notebook.run("NB_N1_SUMA",600, {"useRootDefaultLakehouse": True})

# %%
resultado_nb_n1_suma = json.loads(resultado_nb_n1_suma)

print("status:", resultado_nb_n1_suma["status"])
status_n1 = resultado_nb_n1_suma["status"]

print("n1:", resultado_nb_n1_suma["n1"])
numero_n1 = resultado_nb_n1_suma["n1"]

print("source:", resultado_nb_n1_suma["source"])
source_n1=resultado_nb_n1_suma["source"]

# %%
resultado_nb_n2_suma = mssparkutils.notebook.run("NB_N2_SUMA",600, {"useRootDefaultLakehouse": True})

# %%
resultado_nb_n2_suma = json.loads(resultado_nb_n2_suma)

print("status:", resultado_nb_n2_suma["status"])
status_n2 = resultado_nb_n2_suma["status"]

print("n2:", resultado_nb_n2_suma["n2"])
numero_n2 = resultado_nb_n2_suma["n2"]

print("source:", resultado_nb_n2_suma["source"])
source_n2=resultado_nb_n2_suma["source"]

# %%
suma=numero_n1+numero_n2
print(f"La suma entre numero 1 y numero 2 es: {suma}")
