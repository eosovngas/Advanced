# %%
n1 = "7"
print(type(n1))
# Out:
# StatementMeta(, 076e3524-3a81-4e21-aedd-60984092fd42, 7, Finished, Available, Finished, False)
# <class 'str'>

# %%
if not isinstance(n1, int):
    raise Exception("El número n1 no se expresa como un valor numérico int")
# Out:
# StatementMeta(, 076e3524-3a81-4e21-aedd-60984092fd42, 8, Finished, Available, Finished, False)
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[23], line 2
#       1 if not isinstance(n1, int):
# ----> 2     raise Exception("El número n1 no se expresa como un valor numérico int")
#
# Exception: El número n1 no se expresa como un valor numérico int
