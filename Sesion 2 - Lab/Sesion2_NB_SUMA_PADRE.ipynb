# %%
# %run NB_N1_SUMA
# Out:
# StatementMeta(, 40c8c0ef-11ae-48fe-957d-e900d5e98cee, 7, Finished, , Finished, True)
# <class 'str'>
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[20], line 2
#       1 if not isinstance(n1, int):
# ----> 2     raise Exception("El número n1 no se expresa como un valor numérico int")
#
# Exception: El número n1 no se expresa como un valor numérico int

# %%
# %run NB_N2_SUMA
# Out:
# StatementMeta(, 40c8c0ef-11ae-48fe-957d-e900d5e98cee, -1, Cancelled, , Cancelled, True)

# %%
suma = 7 +10
print(suma)
# Out:
# StatementMeta(, 40c8c0ef-11ae-48fe-957d-e900d5e98cee, -1, Cancelled, , Cancelled, True)
