# %%
import json

# %%
n2=10
try:
    print(f"Numero 2: {n2}")
except Exception as e:
    mssparkutils.notebook.exit(f"ERROR al ingresar numero 2 para la suma: {str(e)}")
 
mssparkutils.notebook.exit(
    json.dumps({
        "status": "OK",
        "n2":n2,
        "source": "Numero 2"
        })
)
