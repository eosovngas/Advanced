# %% [markdown]
# # Consumir Biblioteca de variables en notebooks

# %%
lib = notebookutils.variableLibrary.getLibrary("LIB_OBJ")

print(lib.ID_WORKSPACE)
# Out:
# StatementMeta(, 4c100ed3-41c9-47f8-9daf-af23387075b2, 4, Finished, Available, Finished, False)
# 15a11867-b59e-49e4-b214-5e69c8ace404
